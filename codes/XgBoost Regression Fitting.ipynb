# %% [markdown]
# # Importing The Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams
import numpy as np
import seaborn as sns
from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV
from sklearn.feature_selection import RFECV, SelectFromModel, SelectKBest
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn import metrics
# %matplotlib inline

# %% [markdown]
# # Importing The Datasets

# %%
Stock_hdfc = pd.read_csv('HDFC_FINAL.csv',  index_col=0)

df_Stock_hdfc = Stock_hdfc
#df_Stock_hdfc = df_Stock_hdfc.rename(columns={'HDFC_Close(t)':'Close'})
df_Stock_hdfc.head()
# Out:
#                   Open        High         Low  HDFC_Close(t)   Volume  \
# Date
# 2011-09-16  243.125000  245.000000  238.149994     241.850006  5473504
# 2011-09-19  240.949997  243.500000  238.550003     242.375000  4194610
# 2011-09-20  242.500000  246.625000  241.500000     245.675003  5917634
# 2011-09-21  246.375000  248.824997  244.199997     247.250000  6445698
# 2011-09-22  243.949997  244.500000  232.750000     236.149994  5095544
#
#                 SD20  Upper_Band  Lower_Band  HDFC_Close(t-1)  \
# Date
# 2011-09-16  6.762994  247.223489  220.171512       242.324997
# 2011-09-19  7.003161  248.262574  220.249928       241.850006
# 2011-09-20  7.383917  249.786585  220.250916       242.375000
# 2011-09-21  7.580813  251.216627  220.893376       245.675003
# 2011-09-22  7.431967  251.241435  221.513567       247.250000
#
#             HDFC_Close(t-2)  ...  Week  Is_month_end  Is_month_start  \
# Date                         ...
# 2011-09-16       239.449997  ...    37             0               0
# 2011-09-19       242.324997  ...    38             0               0
# 2011-09-20       241.850006  ...    38             0               0
# 2011-09-21       242.375000  ...    38             0               0
# 2011-09-22       245.675003  ...    38             0               0
#
#             Is_quarter_end  Is_quarter_start  Is_year_end  Is_year_start  \
# Date
# 2011-09-16               0                 0            0              0
# 2011-09-19               0                 0            0              0
# 2011-09-20               0                 0            0              0
# 2011-09-21               0                 0            0              0
# 2011-09-22               0                 0            0              0
#
#             Is_leap_year  Year  Month
# Date
# 2011-09-16             0  2011      9
# 2011-09-19             0  2011      9
# 2011-09-20             0  2011      9
# 2011-09-21             0  2011      9
# 2011-09-22             0  2011      9
#
# [5 rows x 64 columns]

# %%
Stock_bhpl = pd.read_csv('BHARAT_PETROLEUM_FINAL.csv',  index_col=0)

df_Stock_bhpl = Stock_bhpl
#df_Stock_bhpl = df_Stock_bhpl.rename(columns={'BHARAT_PETROLEUM_Close(t)':'Close'})
df_Stock_bhpl.head()
# Out:
#                   Open        High         Low  BHARAT_PETROLEUM_Close(t)  \
# Date
# 2011-09-16  229.846664  231.199997  223.486664                 224.193329
# 2011-09-19  223.333328  223.800003  220.133331                 220.653336
# 2011-09-20  220.000000  221.826660  217.353333                 218.706665
# 2011-09-21  220.000000  222.266663  216.800003                 218.026672
# 2011-09-22  215.866669  216.593338  213.466660                 213.833328
#
#              Volume      SD20  Upper_Band  Lower_Band  \
# Date
# 2011-09-16  8211097  4.114019  239.858038  223.401961
# 2011-09-19  4992840  4.700258  240.309183  221.508149
# 2011-09-20  8540872  5.246042  241.123084  220.138916
# 2011-09-21  6039802  5.950725  241.989784  218.186882
# 2011-09-22  4292655  6.854219  242.747436  215.330562
#
#             Bharat Petroleum_Close(t-1)  Bharat Petroleum_Close(t-2)  ...  \
# Date                                                                  ...
# 2011-09-16                   228.473328                   231.059998  ...
# 2011-09-19                   224.193329                   228.473328  ...
# 2011-09-20                   220.653336                   224.193329  ...
# 2011-09-21                   218.706665                   220.653336  ...
# 2011-09-22                   218.026672                   218.706665  ...
#
#             Week  Is_month_end  Is_month_start  Is_quarter_end  \
# Date
# 2011-09-16    37             0               0               0
# 2011-09-19    38             0               0               0
# 2011-09-20    38             0               0               0
# 2011-09-21    38             0               0               0
# 2011-09-22    38             0               0               0
#
#             Is_quarter_start  Is_year_end  Is_year_start  Is_leap_year  Year  \
# Date
# 2011-09-16                 0            0              0             0  2011
# 2011-09-19                 0            0              0             0  2011
# 2011-09-20                 0            0              0             0  2011
# 2011-09-21                 0            0              0             0  2011
# 2011-09-22                 0            0              0             0  2011
#
#             Month
# Date
# 2011-09-16      9
# 2011-09-19      9
# 2011-09-20      9
# 2011-09-21      9
# 2011-09-22      9
#
# [5 rows x 64 columns]

# %%
Stock_cipla = pd.read_csv('CIPLA_FINAl.csv',  index_col=0)

df_Stock_cipla = Stock_cipla
#df_Stock_cipla = df_Stock_cipla.rename(columns={'CIPLA_Close(t)':'Close'})
df_Stock_cipla.head()
# Out:
#                   Open        High         Low  CIPLA_Close(t)   Volume  \
# Date
# 2011-09-16  284.000000  287.850006  281.549988      282.700012   706838
# 2011-09-19  283.500000  283.500000  274.649994      277.250000  1715520
# 2011-09-20  278.649994  283.000000  277.049988      282.399994   928700
# 2011-09-21  282.350006  285.899994  281.000000      283.500000   680118
# 2011-09-22  281.000000  284.200012  276.350006      277.750000   876968
#
#                 SD20  Upper_Band  Lower_Band  Cipla_Close(t-1)  \
# Date
# 2011-09-16  4.787974  292.563450  273.411553        284.049988
# 2011-09-19  4.939488  292.503978  272.746025        282.700012
# 2011-09-20  4.906447  292.305397  272.679607        277.250000
# 2011-09-21  4.587921  291.343344  272.991660        282.399994
# 2011-09-22  4.692965  291.330931  272.559071        283.500000
#
#             Cipla_Close(t-2)  ...  Week  Is_month_end  Is_month_start  \
# Date                          ...
# 2011-09-16        282.200012  ...    37             0               0
# 2011-09-19        284.049988  ...    38             0               0
# 2011-09-20        282.700012  ...    38             0               0
# 2011-09-21        277.250000  ...    38             0               0
# 2011-09-22        282.399994  ...    38             0               0
#
#             Is_quarter_end  Is_quarter_start  Is_year_end  Is_year_start  \
# Date
# 2011-09-16               0                 0            0              0
# 2011-09-19               0                 0            0              0
# 2011-09-20               0                 0            0              0
# 2011-09-21               0                 0            0              0
# 2011-09-22               0                 0            0              0
#
#             Is_leap_year  Year  Month
# Date
# 2011-09-16             0  2011      9
# 2011-09-19             0  2011      9
# 2011-09-20             0  2011      9
# 2011-09-21             0  2011      9
# 2011-09-22             0  2011      9
#
# [5 rows x 64 columns]

# %%
Stock_coroml = pd.read_csv('COROMANDEL_FINAL.csv',  index_col=0)

df_Stock_coroml = Stock_coroml
#df_Stock_coroml = df_Stock_coroml.rename(columns={'coroml_Close(t)':'Close'})
df_Stock_coroml.head()
# Out:
#                   Open        High         Low  COROMANDEL_Close(t)  Volume  \
# Date
# 2011-09-16  315.299988  329.950012  307.450012           324.200012  409636
# 2011-09-19  318.000000  318.000000  308.700012           309.649994   62561
# 2011-09-20  314.500000  317.899994  310.000000           312.200012   64223
# 2011-09-21  314.850006  320.000000  309.000000           309.850006  104925
# 2011-09-22  306.750000  312.000000  302.100006           303.899994   32327
#
#                 SD20  Upper_Band  Lower_Band  Coromandel_Close(t-1)  \
# Date
# 2011-09-16  9.795728  326.703957  287.521046             306.399994
# 2011-09-19  9.610628  326.033758  287.591245             324.200012
# 2011-09-20  9.315916  325.136834  287.873170             309.649994
# 2011-09-21  8.721751  323.393503  288.506500             312.200012
# 2011-09-22  7.943061  320.966124  289.193879             309.850006
#
#             Coromandel_Close(t-2)  ...  Week  Is_month_end  Is_month_start  \
# Date                               ...
# 2011-09-16             300.200012  ...    37             0               0
# 2011-09-19             306.399994  ...    38             0               0
# 2011-09-20             324.200012  ...    38             0               0
# 2011-09-21             309.649994  ...    38             0               0
# 2011-09-22             312.200012  ...    38             0               0
#
#             Is_quarter_end  Is_quarter_start  Is_year_end  Is_year_start  \
# Date
# 2011-09-16               0                 0            0              0
# 2011-09-19               0                 0            0              0
# 2011-09-20               0                 0            0              0
# 2011-09-21               0                 0            0              0
# 2011-09-22               0                 0            0              0
#
#             Is_leap_year  Year  Month
# Date
# 2011-09-16             0  2011      9
# 2011-09-19             0  2011      9
# 2011-09-20             0  2011      9
# 2011-09-21             0  2011      9
# 2011-09-22             0  2011      9
#
# [5 rows x 64 columns]

# %%
Stock_tcs = pd.read_csv('TCS_FINAL.csv',  index_col=0)

df_Stock_tcs = Stock_tcs
#df_Stock_tcs = df_Stock_tcs.rename(columns={'tcs_Close(t)':'Close'})
df_Stock_tcs.head()
# Out:
#                   Open        High         Low  TCS_Close(t)   Volume  \
# Date
# 2011-09-16  524.000000  536.200012  510.649994    513.875000  4656504
# 2011-09-19  510.750000  516.250000  506.250000    509.024994  2240234
# 2011-09-20  511.049988  532.000000  511.049988    528.974976  3487986
# 2011-09-21  533.974976  533.974976  518.450012    521.750000  2740760
# 2011-09-22  511.500000  517.000000  493.100006    497.200012  3141570
#
#                  SD20  Upper_Band  Lower_Band  TCS_Close(t-1)  TCS_Close(t-2)  \
# Date
# 2011-09-16  19.860088  538.351425  458.911072      520.875000      507.549988
# 2011-09-19  19.545583  539.114916  460.932582      513.875000      520.875000
# 2011-09-20  18.673109  540.594965  465.902529      509.024994      513.875000
# 2011-09-21  15.918955  538.222908  474.547087      528.974976      509.024994
# 2011-09-22  15.651254  538.007506  475.402492      521.750000      528.974976
#
#             ...  Week  Is_month_end  Is_month_start  Is_quarter_end  \
# Date        ...
# 2011-09-16  ...    37             0               0               0
# 2011-09-19  ...    38             0               0               0
# 2011-09-20  ...    38             0               0               0
# 2011-09-21  ...    38             0               0               0
# 2011-09-22  ...    38             0               0               0
#
#             Is_quarter_start  Is_year_end  Is_year_start  Is_leap_year  Year  \
# Date
# 2011-09-16                 0            0              0             0  2011
# 2011-09-19                 0            0              0             0  2011
# 2011-09-20                 0            0              0             0  2011
# 2011-09-21                 0            0              0             0  2011
# 2011-09-22                 0            0              0             0  2011
#
#             Month
# Date
# 2011-09-16      9
# 2011-09-19      9
# 2011-09-20      9
# 2011-09-21      9
# 2011-09-22      9
#
# [5 rows x 64 columns]

# %% [markdown]
# # Train Test Split

# %%
def create_train_test_set(df_Stock):
    
    features = df_Stock.drop(df_Stock.columns[3], axis=1)
    target = df_Stock.iloc[:,3]
    #df_Stock = df_Stock.drop(columns= ['Date_Col'], axis = 1, inplace = True)

    data_len = df_Stock.shape[0]
    print('Historical Stock Data length is - ', str(data_len))

    #create a chronological split for train and testing
    train_split = int(data_len * 0.90)
    print('Training Set length - ', str(train_split))

    #test_split = train_split + int(data_len * 0.10)
    #print('Validat Set length - ', str(int(data_len * 0.1)))

    print('Testing Set length - ', str(int(data_len * 0.10)))

    # Splitting features and target into train, validation and test samples 
    X_train, X_test = features[:train_split], features[train_split:]
    Y_train, Y_test = target[:train_split], target[train_split:]

    #print shape of samples
    print(X_train.shape, X_test.shape)
    print(Y_train.shape, Y_test.shape)
    
    X_train.reset_index(inplace = True)
    X_train.drop(columns = ['Date','Date_Col'], axis= 1, inplace = True)
    
    X_test.reset_index(inplace = True)
    X_test.drop(columns = ['Date','Date_Col'], axis= 1, inplace = True)
    
    
    return X_train, X_test, Y_train, Y_test

# %%
X_train_hdfc, X_test_hdfc, Y_train_hdfc, Y_test_hdfc = create_train_test_set(df_Stock_hdfc)
# Out:
# Historical Stock Data length is -  2760
# Training Set length -  2484
# Testing Set length -  276
# (2484, 63) (276, 63)
# (2484,) (276,)
# C:\Users\HP\AppData\Local\Temp\ipykernel_4160\2443111095.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.drop(columns = ['Date','Date_Col'], axis= 1, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_4160\2443111095.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.drop(columns = ['Date','Date_Col'], axis= 1, inplace = True)

# %%
X_train_bhpl, X_test_bhpl, Y_train_bhpl, Y_test_bhpl = create_train_test_set(df_Stock_bhpl)
# Out:
# Historical Stock Data length is -  2760
# Training Set length -  2484
# Testing Set length -  276
# (2484, 63) (276, 63)
# (2484,) (276,)
# C:\Users\HP\AppData\Local\Temp\ipykernel_4160\2443111095.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.drop(columns = ['Date','Date_Col'], axis= 1, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_4160\2443111095.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.drop(columns = ['Date','Date_Col'], axis= 1, inplace = True)

# %%
X_train_cipla, X_test_cipla, Y_train_cipla, Y_test_cipla = create_train_test_set(df_Stock_cipla)
# Out:
# Historical Stock Data length is -  2760
# Training Set length -  2484
# Testing Set length -  276
# (2484, 63) (276, 63)
# (2484,) (276,)
# C:\Users\HP\AppData\Local\Temp\ipykernel_4160\2443111095.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.drop(columns = ['Date','Date_Col'], axis= 1, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_4160\2443111095.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.drop(columns = ['Date','Date_Col'], axis= 1, inplace = True)

# %%
X_train_coroml, X_test_coroml, Y_train_coroml, Y_test_coroml = create_train_test_set(df_Stock_coroml)
# Out:
# Historical Stock Data length is -  2760
# Training Set length -  2484
# Testing Set length -  276
# (2484, 63) (276, 63)
# (2484,) (276,)
# C:\Users\HP\AppData\Local\Temp\ipykernel_4160\2443111095.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.drop(columns = ['Date','Date_Col'], axis= 1, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_4160\2443111095.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.drop(columns = ['Date','Date_Col'], axis= 1, inplace = True)

# %%
X_train_tcs, X_test_tcs, Y_train_tcs, Y_test_tcs = create_train_test_set(df_Stock_tcs)
# Out:
# Historical Stock Data length is -  2760
# Training Set length -  2484
# Testing Set length -  276
# (2484, 63) (276, 63)
# (2484,) (276,)
# C:\Users\HP\AppData\Local\Temp\ipykernel_4160\2443111095.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.drop(columns = ['Date','Date_Col'], axis= 1, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_4160\2443111095.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.drop(columns = ['Date','Date_Col'], axis= 1, inplace = True)

# %% [markdown]
# # Model Fitting

# %%
from xgboost import XGBRegressor
n_estimators = 100             # Number of boosted trees to fit. default = 100
max_depth = 10                 # Maximum tree depth for base learners. default = 3
learning_rate = 0.2            # Boosting learning rate (xgb’s “eta”). default = 0.1
min_child_weight = 1           # Minimum sum of instance weight(hessian) needed in a child. default = 1
subsample = 1                  # Subsample ratio of the training instance. default = 1
colsample_bytree = 1           # Subsample ratio of columns when constructing each tree. default = 1
colsample_bylevel = 1          # Subsample ratio of columns for each split, in each level. default = 1
gamma = 2                      # Minimum loss reduction required to make a further partition on a leaf node of the tree. default=0
model_seed = 42

# %%
def xgBoost_Regression(X_train, Y_train, X_test, Y_test):
    
    
    xgb = XGBRegressor(seed=model_seed, n_estimators=n_estimators, max_depth=max_depth, learning_rate=learning_rate,
                    min_child_weight=min_child_weight, subsample=subsample, colsample_bytree=colsample_bytree,
                    colsample_bylevel=colsample_bylevel, gamma=gamma)
    xgb.fit(X_train, Y_train.values)
    
    Y_train_pred = xgb.predict(X_train)
    Y_test_pred = xgb.predict(X_test)
    print("Training R-squared: ",round(metrics.r2_score(Y_train.values,Y_train_pred),2))
    print('Training Mean Squared Error:', round(metrics.mean_squared_error(Y_train.values,Y_train_pred), 2)) 
    print("Training RMSE: ",round(np.sqrt(metrics.mean_squared_error(Y_train.values,Y_train_pred)),2))
    print("Training MAE: ",round(metrics.mean_absolute_error(Y_train.values,Y_train_pred),2))
    
    print(' ')

    print("Testing R-squared: ",round(metrics.r2_score(Y_test.values,Y_test_pred),2))
    print('Testing Mean Squared Error:', round(metrics.mean_squared_error(Y_test.values,Y_test_pred), 2)) 
    print("Testing RMSE: ",round(np.sqrt(metrics.mean_squared_error(Y_test.values,Y_test_pred)),2))
    print("Testing MAE: ",round(metrics.mean_absolute_error(Y_test.values,Y_test_pred),2))
    
    print(' ')
    
    df_pred = pd.DataFrame(Y_test.values, columns=['Actual'], index=Y_test.index)
    df_pred['Predicted'] = Y_test_pred
    df_pred = df_pred.reset_index()
    df_pred.loc[:, 'Date'] = pd.to_datetime(df_pred['Date'],format='%Y-%m-%d')
    
    df_pred[['Actual', 'Predicted']].plot(figsize = (12,8))
    
    return df_pred

# %% [markdown]
# ### HDFC

# %%
xgBoost_Regression(X_train_hdfc, Y_train_hdfc, X_test_hdfc, Y_test_hdfc)
# Out:
# Training R-squared:  1.0
# Training Mean Squared Error: 0.28
# Training RMSE:  0.53
# Training MAE:  0.4
#
# Testing R-squared:  0.97
# Testing Mean Squared Error: 237.85
# Testing RMSE:  15.42
# Testing MAE:  10.98
#           Date       Actual    Predicted
# 0   2021-10-20  1673.849976  1685.072998
# 1   2021-10-21  1676.300049  1685.614380
# 2   2021-10-22  1680.750000  1685.535645
# 3   2021-10-25  1657.000000  1684.389160
# 4   2021-10-26  1652.750000  1684.504028
# ..         ...          ...          ...
# 271 2022-11-23  1599.150024  1590.154053
# 272 2022-11-24  1625.150024  1619.415527
# 273 2022-11-25  1617.650024  1614.214844
# 274 2022-11-28  1600.250000  1595.855347
# 275 2022-11-29  1597.849976  1599.108765
#
# [276 rows x 3 columns]

# %% [markdown]
# ### Bharat Petrolium

# %%
xgBoost_Regression(X_train_bhpl, Y_train_bhpl, X_test_bhpl, Y_test_bhpl)
# Out:
# Training R-squared:  1.0
# Training Mean Squared Error: 0.17
# Training RMSE:  0.42
# Training MAE:  0.33
#
# Testing R-squared:  0.99
# Testing Mean Squared Error: 0.59
# Testing RMSE:  0.77
# Testing MAE:  0.63
#           Date     Actual  Predicted
# 0   2021-10-20  72.900002  70.870995
# 1   2021-10-21  71.550003  69.561211
# 2   2021-10-22  69.300003  69.331581
# 3   2021-10-25  68.699997  67.621040
# 4   2021-10-26  71.650002  70.905479
# ..         ...        ...        ...
# 271 2022-11-23  74.949997  75.577629
# 272 2022-11-24  74.800003  75.355423
# 273 2022-11-25  81.949997  80.483444
# 274 2022-11-28  81.400002  80.786934
# 275 2022-11-29  81.050003  80.837807
#
# [276 rows x 3 columns]

# %% [markdown]
# ### Cipla

# %%
xgBoost_Regression(X_train_cipla, Y_train_cipla, X_test_cipla, Y_test_cipla)
# Out:
# Training R-squared:  1.0
# Training Mean Squared Error: 0.24
# Training RMSE:  0.49
# Training MAE:  0.38
#
# Testing R-squared:  0.28
# Testing Mean Squared Error: 4240.27
# Testing RMSE:  65.12
# Testing MAE:  38.96
#           Date       Actual   Predicted
# 0   2021-10-20   905.900024  905.416565
# 1   2021-10-21   911.549988  902.019226
# 2   2021-10-22   896.349976  897.510620
# 3   2021-10-25   901.849976  906.045105
# 4   2021-10-26   907.500000  907.852478
# ..         ...          ...         ...
# 271 2022-11-23  1108.000000  979.743958
# 272 2022-11-24  1095.349976  974.270203
# 273 2022-11-25  1105.349976  979.577881
# 274 2022-11-28  1101.750000  978.510010
# 275 2022-11-29  1121.150024  980.533997
#
# [276 rows x 3 columns]

# %% [markdown]
# ### Coromandel

# %%
xgBoost_Regression(X_train_coroml, Y_train_coroml, X_test_coroml, Y_test_coroml)
# Out:
# Training R-squared:  1.0
# Training Mean Squared Error: 0.3
# Training RMSE:  0.55
# Training MAE:  0.42
#
# Testing R-squared:  0.69
# Testing Mean Squared Error: 3373.08
# Testing RMSE:  58.08
# Testing MAE:  36.6
#           Date      Actual   Predicted
# 0   2021-10-20  835.500000  831.677917
# 1   2021-10-21  830.650024  834.210388
# 2   2021-10-22  824.250000  831.206360
# 3   2021-10-25  814.150024  796.723877
# 4   2021-10-26  807.900024  808.868042
# ..         ...         ...         ...
# 271 2022-11-23  902.750000  904.140503
# 272 2022-11-24  901.250000  901.368286
# 273 2022-11-25  920.349976  912.277222
# 274 2022-11-28  918.650024  905.390625
# 275 2022-11-29  918.500000  902.678894
#
# [276 rows x 3 columns]

# %% [markdown]
# ### TCS

# %%
xgBoost_Regression(X_train_tcs, Y_train_tcs, X_test_tcs, Y_test_tcs)
# Out:
# Training R-squared:  1.0
# Training Mean Squared Error: 0.38
# Training RMSE:  0.62
# Training MAE:  0.46
#
# Testing R-squared:  0.97
# Testing Mean Squared Error: 1903.9
# Testing RMSE:  43.63
# Testing MAE:  33.87
#           Date       Actual    Predicted
# 0   2021-10-20  3608.850098  3591.198486
# 1   2021-10-21  3532.500000  3581.146729
# 2   2021-10-22  3498.850098  3517.124756
# 3   2021-10-25  3492.949951  3535.172852
# 4   2021-10-26  3482.600098  3533.450439
# ..         ...          ...          ...
# 271 2022-11-23  3308.300049  3354.816650
# 272 2022-11-24  3380.149902  3373.525391
# 273 2022-11-25  3389.649902  3496.025146
# 274 2022-11-28  3395.250000  3499.398438
# 275 2022-11-29  3397.350098  3494.678955
#
# [276 rows x 3 columns]
